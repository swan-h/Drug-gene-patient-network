# %%
import pandas as pd

# %%
db_data = pd.read_csv("uniprotlinks.csv")

# %%
print(db_data)
# Out:
#       DrugBank ID                          Name               Type UniProt ID  \
# 0         DB00001                     Lepirudin        BiotechDrug     P00734
# 1         DB00002                     Cetuximab        BiotechDrug     P00533
# 2         DB00002                     Cetuximab        BiotechDrug     O75015
# 3         DB00002                     Cetuximab        BiotechDrug     P00736
# 4         DB00002                     Cetuximab        BiotechDrug     P02745
# 5         DB00002                     Cetuximab        BiotechDrug     P02746
# 6         DB00002                     Cetuximab        BiotechDrug     P02747
# 7         DB00002                     Cetuximab        BiotechDrug     P08637
# 8         DB00002                     Cetuximab        BiotechDrug     P09871
# 9         DB00002                     Cetuximab        BiotechDrug     P12314
# 10        DB00002                     Cetuximab        BiotechDrug     P12318
# ...

# %%
count_unique = db_data.apply(lambda x: len(x.unique()))

# %%
print(count_unique)
# Out:
# DrugBank ID     6700
# Name            6700
# Type               2
# UniProt ID      4088
# UniProt Name    3608
# dtype: int64

# %%
column = db_data["UniProt ID"]

# %%
import mygene as mg

# %%
mg = mg.MyGeneInfo()

# %%
out = mg.querymany(column, scopes='uniprot', fields='symbol', species='humans', returnall=True, as_dataframe=True)
# Out:
# querying 1-1000...done.
# querying 1001-2000...done.
# querying 2001-3000...done.
# querying 3001-4000...done.
# querying 4001-5000...done.
# querying 5001-6000...done.
# querying 6001-7000...done.
# querying 7001-8000...done.
# querying 8001-9000...done.
# querying 9001-10000...done.
# querying 10001-11000...done.
# querying 11001-12000...done.
# querying 12001-13000...done.
# querying 13001-14000...done.
# querying 14001-15000...done.
# querying 15001-16000...done.
# querying 16001-16168...done.
# Finished.
# 1706 input query terms found dup hits:
# 	[('P00734', 102), ('P00533', 23), ('O75015', 19), ('P00736', 20), ('P02745', 18), ('P02746', 18), ('
# 2071 input query terms found no hit:
# 	['Q53I07', 'P13843', 'Q2TU84', 'Q49AK1', 'Q53ET4', 'Q59GM9', 'Q59HE2', 'Q6IBS8', 'Q9BXA1', 'Q9UGI5',

# %%
out['out']
# Out:
#            _id     _score notfound    symbol
# query
# P00734    2147  20.186922      NaN        F2
# P00533    1956  19.741434      NaN      EGFR
# O75015    2215  20.188843      NaN    FCGR3B
# P00736     715  21.690075      NaN       C1R
# P02745     712  22.844710      NaN      C1QA
# P02746     713  21.668577      NaN      C1QB
# P02747     714  20.825530      NaN      C1QC
# P08637    2214  20.264400      NaN    FCGR3A
# P09871     716  21.667978      NaN       C1S
# P12314    2209  21.633108      NaN    FCGR1A
# P12318    2212  20.816162      NaN    FCGR2A
# P31994    2213  12.627164      NaN    FCGR2B
# P31995    2213  13.025829      NaN    FCGR2B
# P31995    9103   6.721117      NaN    FCGR2C
# P01589    3559  20.821302      NaN     IL2RA
# P14784    3560  21.648472      NaN     IL2RB
# P31785    3561  20.867012      NaN     IL2RG
# P01375    7124  20.220304      NaN       TNF
# P20333    7133  20.845577      NaN  TNFRSF1B
# P12314    2209  21.639082      NaN    FCGR1A
# ...

# %%
print(type(out))
# Out:
# <class 'dict'>

# %%
import collections as cl

# %%
cl.Counter(column)
# Out:
# Counter({'P00734': 102,
#          'P00533': 23,
#          'O75015': 19,
#          'P00736': 20,
#          'P02745': 18,
#          'P02746': 18,
#          'P02747': 18,
#          'P08637': 19,
#          'P09871': 13,
#          'P12314': 21,
#          'P12318': 19,
#          'P31994': 20,
#          'P31995': 19,
#          'P01589': 4,
#          'P14784': 4,
#          'P31785': 2,
#          'P01375': 30,
#          'P20333': 1,
#          'P01374': 1,
#          'P30968': 13,
#          'P48551': 10,
#          'P17181': 11,
#          'P00747': 11,
#          'P02671': 8,
#          'Q03405': 6,
#          'P05121': 8,
#          'Q02643': 2,
#          'P19235': 6,
#          'P00749': 34,
#          'P00750': 7,
#          'P05120': 2,
#          'P05154': 3,
#          'P98164': 4,
#          'Q9Y5Y6': 2,
#          'P14543': 1,
#          'P22888': 7,
#          'P30988': 2,
#          'Q99062': 5,
#          'P08246': 6,
#          'P15509': 3,
# ...

# %%
for key in out:
    print(out[key])
# Out:
#            _id     _score notfound    symbol
# query
# P00734    2147  20.186922      NaN        F2
# P00533    1956  19.741434      NaN      EGFR
# O75015    2215  20.188843      NaN    FCGR3B
# P00736     715  21.690075      NaN       C1R
# P02745     712  22.844710      NaN      C1QA
# P02746     713  21.668577      NaN      C1QB
# P02747     714  20.825530      NaN      C1QC
# P08637    2214  20.264400      NaN    FCGR3A
# P09871     716  21.667978      NaN       C1S
# P12314    2209  21.633108      NaN    FCGR1A
# P12318    2212  20.816162      NaN    FCGR2A
# P31994    2213  12.627164      NaN    FCGR2B
# P31995    2213  13.025829      NaN    FCGR2B
# P31995    9103   6.721117      NaN    FCGR2C
# P01589    3559  20.821302      NaN     IL2RA
# P14784    3560  21.648472      NaN     IL2RB
# P31785    3561  20.867012      NaN     IL2RG
# P01375    7124  20.220304      NaN       TNF
# P20333    7133  20.845577      NaN  TNFRSF1B
# P12314    2209  21.639082      NaN    FCGR1A
# ...

# %%
print(type(query[0]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-b25462d91cc4> in <module>()
# ----> 1 print(type(query[0]))
#
# NameError: name 'query' is not defined
